# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\taeeu\anaconda3\lib\site-packages (0.19.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx>=2.2 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (2.5)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (2.16.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (9.0.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (1.7.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (1.2.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (1.22.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (21.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\taeeu\anaconda3\lib\site-packages (from scikit-image) (2022.2.9)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\taeeu\anaconda3\lib\site-packages (from networkx>=2.2->scikit-image) (5.0.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\taeeu\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image) (2.4.7)

# %%
from skimage.io import imread
from skimage.transform import resize
from matplotlib import pyplot as plt
import matplotlib.cm as cm
# Out:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
example_file=("https://upload.wikimedia.org/wikipedia/commons/4/4f/Felis_silvestris_catus_lying_on_rice_straw.jpg")
image = imread(example_file)
plt.imshow(image)
plt.show()

# %%
#이미지 확대
image2= image[500:3000, 500:4000]
plt.imshow(image2)
plt.show()

# %%
# resizing
image3 = resize(image, (1250, 1750), mode='symmetric')
plt.imshow(image3)
print("원본 이미지 :", image.shape)
print("resizing 후 :", image3.shape)
# Out:
# 원본 이미지 : (3207, 4811, 3)
# resizing 후 : (1250, 1750, 3)

# %%
#gray
image4 = imread(example_file, as_gray=True)
plt.imshow(image4, cmap=cm.gray)
plt.show()
